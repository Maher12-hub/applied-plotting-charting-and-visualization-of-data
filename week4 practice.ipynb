# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
plt.style.use('seaborn-colorblind')

# %%
np.random.seed(123)
df=pd.DataFrame({'A':np.random.randn(365).cumsum(0),
                 'B':np.random.randn(365).cumsum(0)+20,
                 'C':np.random.randn(365).cumsum(0)-20},
                index=pd.date_range('1/1/2017',periods=365))
df.plot();
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
df.plot('A','B',kind='scatter')
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
df.plot.scatter('A','C',c='B',s=df['B'],cmap='viridis')
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
df.plot.box()
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
ax=df.plot.scatter('A','B',cmap='viridis')
ax.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
df.plot.line()
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
import seaborn as sns
sns.set_style('ticks')
df.plot.hist()
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
df.plot.kde()
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
iris=pd.read_csv('iris.csv')
iris['Name'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df1=iris[iris['Name']=='Iris-setosa']
df1.plot();
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
df1.plot('SepalLength','SepalWidth',kind='scatter')
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
#df1.plot.scatter('SepalLength','SepalWidth',cmap='viridis')
#df1.plot.box()
#df1.plot.hist()
ax=df1.plot.kde()
ax.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
sns.pairplot(iris)
# Out:
# <img src="data:image/png;base64,..." width="999.7333333333333">

# %%
import pandas as pd
plt.figure()
pd.tools.plotting.parallel_coordinates(iris,'Name')
# Out:
# <img src="data:image/png;base64,..." width="639.4">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-f356249d5e8f> in <module>
#       1 import pandas as pd
#       2 plt.figure()
# ----> 3 pd.tools.plotting.parallel_coordinates(iris,'Name')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     260             return _SparseArray
#     261
# --> 262         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     263
#     264
#
# AttributeError: module 'pandas' has no attribute 'tools'

# %%
df1=iris[iris['Name']=='Iris-virginica']
df1.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
df1.plot.scatter('SepalLength','SepalWidth')
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
df1.plot.box()
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
df1.plot.kde()
# Out:
# <img src="data:image/png;base64,..." width="639.4">

# %%
pd.Series(np.random.normal(0,10,1000),name='v1')
# Out:
# 0     -17.258900
# 1       6.112378
# 2      13.093510
# 3       6.958797
# 4       3.203082
#          ...
# 995   -16.471157
# 996    -6.896402
# 997    16.780687
# 998    11.841187
# 999    -7.115727
# Name: v1, Length: 1000, dtype: float64

# %%
np.random.seed(1234)
v1=pd.Series(np.random.normal(0,10,1000),name='v1')
v2=pd.Series(2*v1+np.random.normal(60,15,1000),name='v2')
plt.figure(figsize=(6,3))
sns.set_context('notebook')
plt.hist(v1,alpha=0.5,bins=20,label='v1');
plt.hist(v2,alpha=0.5,bins=30,label='v2');
plt.legend();
# Out:
# <img src="data:image/png;base64,..." width="599.5333333333333">

# %%
plt.figure()
plt.hist([v1,v2],alpha=0.5,histtype='barstacked',normed=True,label=['v1','v2'])
v3=np.concatenate((v1,v2))
sns.kdeplot(v3)
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.4">
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.

# %%
plt.figure()
sns.distplot(v3,hist_kws={'color':'blue'},kde_kws={'color':'navy'})
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.jointplot(v1,v2,alpha=0.4,kind='hex')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
grid=sns.jointplot(v1,v2,alpha=0.4)
grid.ax_joint.set_aspect('equal')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1676: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   f = plt.figure(figsize=(height, height))
# <img src="data:image/png;base64,..." width="600">

# %%
sns.set_style('white')
sns.jointplot(v1,v2,kind='kde',space=0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1676: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   f = plt.figure(figsize=(height, height))
# <img src="data:image/png;base64,..." width="600">

# %%
plt.figure(figsize=(6,3))
sns.pairplot(iris,hue='Name',diag_kind='kde')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <img src="data:image/png;base64,..." width="600">
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1295: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   squeeze=False)
# <img src="data:image/png;base64,..." width="1145.8333333333335">

# %%
sns.pairplot(iris,hue='Name',diag_kind='kde',size=2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1295: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   squeeze=False)
# <img src="data:image/png;base64,..." width="945.8333333333334">

# %%
plt.figure(figsize=(8,6))
plt.subplot(1,2,1)
sns.swarmplot(x='Name',y='PetalLength',data=iris,palette='Set2')
plt.subplot(1,2,2)
sns.violinplot(x='Name',y='PetalLength',data=iris,palette='Set1')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <img src="data:image/png;base64,..." width="800">

# %%
plt.figure()
plt.hist(df1['SepalLength'],bins=20,label='sepal_length',histtype='barstacked')
plt.hist(df1['PetalLength'],bins=20,alpha=0.4,label='petal_lentgh',histtype='barstacked',color='b')
plt.legend()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.hist(['SetalLength','PetalLength'],alpha=0.4,bins=5,histtype='barstacked')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <img src="data:image/png;base64,..." width="640">
# (array([1., 0., 0., 0., 1.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <a list of 5 Patch objects>)

# %%
plt.figure()
sns.distplot(df1['SepalLength'],hist_kws={'color':'Teal'},kde_kws={'color':'Navy'})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <img src="data:image/png;base64,..." width="640">

# %%
sns.jointplot(x='SepalLength',y='PetalLength',data=df1,kind='hex')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1676: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   f = plt.figure(figsize=(height, height))
# <img src="data:image/png;base64,..." width="600">

# %%
sns.set_style('white')
sns.pairplot(iris,hue='Name',diag_kind='kde')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1295: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   squeeze=False)
# <img src="data:image/png;base64,..." width="1145.8333333333335">

# %%
plt.figure(figsize=(8,6))
plt.subplot(1,2,1)
sns.swarmplot(x='Name',y='SepalLength',data=iris)
plt.subplot(1,2,2)
sns.violinplot(x='Name',y=)
